# %% [markdown]
# # Time SeriesAnalytics Homework #01

# %% [markdown]
# ## Q1

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
x_24 = np.arange(0,8*np.pi,0.1)
y_24 = np.cos(x)-x/6

# %%
plt.plot(x_24,y_24)
plt.show()

# %%
x_24 = np.arange(0,8*np.pi,0.1)
y_24 = np.cos(x)-x/6

# %% [markdown]
# ###### we may use cos function, and minus a certain x value to generate a alike curve, which similar  to the question

# %% [markdown]
# ## Q2

# %%
def Predict_a_Time_Series(Time_length):
    #    predict a time series
    predictions = []
    for epoch in range(0,Time_length):
        value = Make_Prediction(epoch)
        predictions.append(value)
    return predictions

# %%
def Make_Prediction(epoch):
    #    return prediction value. 
    value = math.cos(2*math.pi*((epoch/12)+(np.random.uniform(0,1))))
    return value

# %%
Predictions = Predict_a_Time_Series(48)

# %%
plt.plot(Predictions)
plt.show()

# %% [markdown]
# ###### we may discover a repeating pattern in this time series function
