# %% [markdown]
# ### import package

# %%
import pandas as pd
import os

# %% [markdown]
# ### settings

# %%
output_name = "(2021)"
output_path = r"C:\Users\TerryYang\Desktop\Github\2021-TSA-Assignment-NTUIIE\Final"
input_path = r"C:\Users\TerryYang\Desktop\Github\2021-TSA-Assignment-NTUIIE\Final\Original_Datasets"

# %%
# merge 12 datasets to df
output_name = "(2021)"
output_path = r"C:\Users\TerryYang\Desktop\Github\2021-TSA-Assignment-NTUIIE\Final"
input_path = r"C:\Users\TerryYang\Desktop\Github\2021-TSA-Assignment-NTUIIE\Final\Original_Datasets"
df = pd.DataFrame()  
directory = os.path.join(input_path)
for root,dirs,files in os.walk(directory):
    for i in range(0,len(files)):      
        df_new = pd.read_csv(input_path + '\\' + files[i])
        df = df.append(df_new)
        print("append file:" + files[i])
# Out:
# append file:(2021_01).csv
# append file:(2021_02).csv
# append file:(2021_03).csv
# append file:(2021_04).csv
# append file:(2021_05).csv
# append file:(2021_06).csv
# append file:(2021_07).csv
# append file:(2021_08).csv
# append file:(2021_09).csv
# append file:(2021_10).csv
# append file:(2021_11).csv
# append file:(2021_12).csv

# %%
# output csv
df.to_csv(output_name + ".csv")
df
# Out:
#     SiteName County   AQI Pollutant Status   SO2    CO    O3  O3_8hr  PM10  \
# 0         萬華    臺北市  83.0     細懸浮微粒     普通  10.6  1.17  15.6    27.0  68.0
# 1         萬華    臺北市  68.0     細懸浮微粒     普通   7.8  1.06  24.3    31.0  61.0
# 2         萬華    臺北市  64.0      二氧化氮     普通   8.4  1.17  14.3    33.0  60.0
# 3         萬華    臺北市  39.0       NaN     良好   2.5  0.47  26.3    37.0  21.0
# 4         萬華    臺北市  43.0       NaN     良好   2.4  0.44  25.4    39.0  24.0
# ..       ...    ...   ...       ...    ...   ...   ...   ...     ...   ...
# 712       萬華    臺北市  74.0     細懸浮微粒     普通   1.1  0.26  37.8    35.0  40.0
# 713       萬華    臺北市  74.0     細懸浮微粒     普通   0.8  0.28  36.6    35.0  40.0
# 714       萬華    臺北市  73.0     細懸浮微粒     普通   0.7  0.30  35.1    35.0  48.0
# 715       萬華    臺北市  68.0     細懸浮微粒     普通   1.0  0.33  34.3    34.0  49.0
# 716       萬華    臺北市  66.0     細懸浮微粒     普通   0.8  0.36  35.5    34.0  51.0
#
#      ...  WindDirec  DataCreationDate  Unit  CO_8hr  PM2.5_AVG  PM10_AVG  \
# 0    ...      290.0   2021/1/31 23:00   NaN     0.7       28.0      44.0
# 1    ...      284.0   2021/1/31 22:00   NaN     0.6       22.0      36.0
# 2    ...      293.0   2021/1/31 21:00   NaN     0.5       17.0      30.0
# 3    ...      211.0   2021/1/31 20:00   NaN     0.5       12.0      23.0
# 4    ...      109.0   2021/1/31 19:00   NaN     0.5       13.0      25.0
# ..   ...        ...               ...   ...     ...        ...       ...
# 712  ...       86.0  2021-12-01 04:00   NaN     0.3       25.0      42.0
# 713  ...       47.0  2021-12-01 03:00   NaN     0.3       25.0      43.0
# 714  ...       29.0  2021-12-01 02:00   NaN     0.4       24.0      42.0
# 715  ...       74.0  2021-12-01 01:00   NaN     0.4       23.0      39.0
# 716  ...       50.0  2021-12-01 00:00   NaN     0.4       22.0      35.0
#
#     SO2_AVG   Longitude   Latitude  SiteId
# 0       3.0  121.507972  25.046503      13
# 1       2.0  121.507972  25.046503      13
# 2       2.0  121.507972  25.046503      13
# 3       2.0  121.507972  25.046503      13
# 4       2.0  121.507972  25.046503      13
# ..      ...         ...        ...     ...
# 712     0.0  121.507972  25.046503      13
# 713     0.0  121.507972  25.046503      13
# 714     0.0  121.507972  25.046503      13
# 715     0.0  121.507972  25.046503      13
# 716     0.0  121.507972  25.046503      13
#
# [8586 rows x 25 columns]
