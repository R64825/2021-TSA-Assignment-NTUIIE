# %% [markdown]
# ### import package

# %%
import pandas as pd

# %% [markdown]
# ### settings

# %%
output_name = "(2021)_Preprocessed"
output_path = r"C:\Users\TerryYang\Desktop\Github\2021-TSA-Assignment-NTUIIE\Final"
input_path = r"C:\Users\TerryYang\(2021).csv"

# %%
# read dataset
df = pd.read_csv(input_path)

# %%
# sort by date time
df['Date'] =pd.to_datetime(df.DataCreationDate)
df['Date'] = pd.to_datetime(df['Date'], format="%Y%m%d:%H:%M:%S.%f").sort_values()
df = df.sort_values(by='Date',ascending=True)
df.head()
# Out:
#      Unnamed: 0 SiteName County   AQI Pollutant Status  SO2    CO    O3  \
# 699         699       萬華    臺北市  53.0     細懸浮微粒     普通  2.4  0.28  26.0
# 698         698       萬華    臺北市  53.0     細懸浮微粒     普通  2.4  0.28  26.0
# 697         697       萬華    臺北市  51.0     細懸浮微粒     普通  1.0  0.38  21.4
# 696         696       萬華    臺北市  45.0       NaN     良好  1.5  0.33  22.5
# 695         695       萬華    臺北市  45.0       NaN     良好  1.4  0.30  25.0
#
#      O3_8hr  ...  DataCreationDate  Unit  CO_8hr  PM2.5_AVG  PM10_AVG  \
# 699    17.0  ...    2021/1/1 00:00   NaN    0.40       16.0      26.0
# 698    17.0  ...    2021/1/1 01:00   NaN    0.40       16.0      26.0
# 697    17.0  ...    2021/1/1 02:00   NaN    0.39       16.0      26.0
# 696    20.0  ...    2021/1/1 04:00   NaN    0.35       14.0      25.0
# 695    21.0  ...    2021/1/1 05:00   NaN    0.33       14.0      24.0
#
#      SO2_AVG   Longitude   Latitude  SiteId                Date
# 699      1.0  121.507972  25.046503      13 2021-01-01 00:00:00
# 698      1.0  121.507972  25.046503      13 2021-01-01 01:00:00
# 697      1.0  121.507972  25.046503      13 2021-01-01 02:00:00
# 696      1.0  121.507972  25.046503      13 2021-01-01 04:00:00
# 695      1.0  121.507972  25.046503      13 2021-01-01 05:00:00
#
# [5 rows x 27 columns]

# %%
# finding missing value
before = len(df)
df = df.set_index('Date')
df = df.reindex(pd.date_range(start=df.index[0], end=df.index[-1], freq='1h'))
df['Date'] = df.index
df = df.reset_index()
df = df.drop(columns = ['index'])
df = df.drop(columns = ['DataCreationDate'])
df = df.drop(columns = ['Unnamed: 0'])
print("Missing: "+ str(len(df)-before)+" data")
# Out:
# Missing: 174 data

# %%
# filling missing data with int(mean)
df['AQI']=df['AQI'].fillna(int(df['AQI'].mean()))
df['CO']=df['CO'].fillna(df['CO'].mean())
df['PM2.5_AVG']=df['PM2.5_AVG'].fillna(int(df['PM2.5_AVG'].mean()))
df['PM2.5']=df['PM2.5'].fillna(int(df['PM2.5'].mean()))

# %%
# output csv
df.to_csv(output_name + ".csv")
df
# Out:
#      SiteName County   AQI Pollutant Status  SO2        CO    O3  O3_8hr  \
# 0          萬華    臺北市  53.0     細懸浮微粒     普通  2.4  0.280000  26.0    17.0
# 1          萬華    臺北市  53.0     細懸浮微粒     普通  2.4  0.280000  26.0    17.0
# 2          萬華    臺北市  51.0     細懸浮微粒     普通  1.0  0.380000  21.4    17.0
# 3         NaN    NaN  44.0       NaN    NaN  NaN  0.392341   NaN     NaN
# 4          萬華    臺北市  45.0       NaN     良好  1.5  0.330000  22.5    20.0
# ...       ...    ...   ...       ...    ...  ...       ...   ...     ...
# 8755       萬華    臺北市  42.0       NaN     良好  0.9  0.340000  28.6    31.0
# 8756       萬華    臺北市  41.0       NaN     良好  0.9  0.330000  27.7    30.0
# 8757       萬華    臺北市  38.0       NaN     良好  0.9  0.310000  27.2    29.0
# 8758       萬華    臺北市  37.0       NaN     良好  0.9  0.310000  27.0    28.0
# 8759       萬華    臺北市  34.0       NaN     良好  1.0  0.320000  28.0    27.0
#
#       PM10  ...  WindDirec  Unit  CO_8hr  PM2.5_AVG  PM10_AVG  SO2_AVG  \
# 0     26.0  ...       76.0   NaN    0.40       16.0      26.0      1.0
# 1     26.0  ...       76.0   NaN    0.40       16.0      26.0      1.0
# 2     25.0  ...       88.0   NaN    0.39       16.0      26.0      1.0
# 3      NaN  ...        NaN   NaN     NaN       12.0       NaN      NaN
# 4     23.0  ...      102.0   NaN    0.35       14.0      25.0      1.0
# ...    ...  ...        ...   ...     ...        ...       ...      ...
# 8755  24.0  ...      106.0   NaN    0.30       13.0      29.0      1.0
# 8756  15.0  ...       86.0   NaN    0.30       13.0      27.0      1.0
# 8757  14.0  ...       85.0   NaN    0.30       12.0      25.0      1.0
# 8758  15.0  ...       91.0   NaN    0.30       11.0      22.0      1.0
# 8759  15.0  ...       93.0   NaN    0.30       11.0      19.0      1.0
#
#        Longitude   Latitude  SiteId                Date
# 0     121.507972  25.046503    13.0 2021-01-01 00:00:00
# 1     121.507972  25.046503    13.0 2021-01-01 01:00:00
# 2     121.507972  25.046503    13.0 2021-01-01 02:00:00
# 3            NaN        NaN     NaN 2021-01-01 03:00:00
# 4     121.507972  25.046503    13.0 2021-01-01 04:00:00
# ...          ...        ...     ...                 ...
# 8755  121.507972  25.046503    13.0 2021-12-31 19:00:00
# 8756  121.507972  25.046503    13.0 2021-12-31 20:00:00
# 8757  121.507972  25.046503    13.0 2021-12-31 21:00:00
# 8758  121.507972  25.046503    13.0 2021-12-31 22:00:00
# 8759  121.507972  25.046503    13.0 2021-12-31 23:00:00
#
# [8760 rows x 25 columns]
